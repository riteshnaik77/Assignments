# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/win10/Desktop/DATA SCIENCE/ExcelR/Assignment Given (Untouched)/3)Logistic Regression/Assignment Given/creditcard.csv",index_col=0)

# %%
df.head()
# Out:
#   card  reports       age  income     share  expenditure owner selfemp  \
# 1  yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 2  yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 3  yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 4  yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 5  yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
#
#    dependents  months  majorcards  active
# 1           3      54           1      12
# 2           3      34           1      13
# 3           4      58           1       5
# 4           0      25           1       7
# 5           2      64           1       5

# %%
df["card"].value_counts()
# Out:
# yes    1023
# no      296
# Name: card, dtype: int64

# %%
df["owner"].value_counts()
# Out:
# no     738
# yes    581
# Name: owner, dtype: int64

# %%
df["selfemp"].value_counts()
# Out:
# no     1228
# yes      91
# Name: selfemp, dtype: int64

# %%
df
# Out:
#      card  reports       age  income     share  expenditure owner selfemp  \
# 1     yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 2     yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 3     yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 4     yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 5     yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
# ...   ...      ...       ...     ...       ...          ...   ...     ...
# 1315  yes        0  33.58333  4.5660  0.002146     7.333333   yes      no
# 1316   no        5  23.91667  3.1920  0.000376     0.000000    no      no
# 1317  yes        0  40.58333  4.6000  0.026513   101.298300   yes      no
# 1318  yes        0  32.83333  3.7000  0.008999    26.996670    no     yes
# 1319  yes        0  48.25000  3.7000  0.111619   344.157500   yes      no
#
#       dependents  months  majorcards  active
# ...

# %%
# Converting Text to Numerical Data----------
df["owner"]= df["owner"].map({'yes':1,'no':0})
df["selfemp"]=df["selfemp"].map({"yes":1,"no":0})
df["card"]=df["card"].map({"yes":1,"no":0})

# %%
df
# Out:
#       card  reports       age  income     share  expenditure  owner  selfemp  \
# 1        1        0  37.66667  4.5200  0.033270   124.983300      1        0
# 2        1        0  33.25000  2.4200  0.005217     9.854167      0        0
# 3        1        0  33.66667  4.5000  0.004156    15.000000      1        0
# 4        1        0  30.50000  2.5400  0.065214   137.869200      0        0
# 5        1        0  32.16667  9.7867  0.067051   546.503300      1        0
# ...    ...      ...       ...     ...       ...          ...    ...      ...
# 1315     1        0  33.58333  4.5660  0.002146     7.333333      1        0
# 1316     0        5  23.91667  3.1920  0.000376     0.000000      0        0
# 1317     1        0  40.58333  4.6000  0.026513   101.298300      1        0
# 1318     1        0  32.83333  3.7000  0.008999    26.996670      0        1
# 1319     1        0  48.25000  3.7000  0.111619   344.157500      1        0
#
#       dependents  months  majorcards  active
# ...

# %%
df.isnull().sum()
# Out:
# card           0
# reports        0
# age            0
# income         0
# share          0
# expenditure    0
# owner          0
# selfemp        0
# dependents     0
# months         0
# majorcards     0
# active         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
df.describe()
# Out:
#               card      reports          age       income        share  \
# count  1319.000000  1319.000000  1319.000000  1319.000000  1319.000000
# mean      0.775588     0.456406    33.213103     3.365376     0.068732
# std       0.417353     1.345267    10.142783     1.693902     0.094656
# min       0.000000     0.000000     0.166667     0.210000     0.000109
# 25%       1.000000     0.000000    25.416670     2.243750     0.002316
# 50%       1.000000     0.000000    31.250000     2.900000     0.038827
# 75%       1.000000     0.000000    39.416670     4.000000     0.093617
# max       1.000000    14.000000    83.500000    13.500000     0.906320
#
#        expenditure        owner      selfemp   dependents       months  \
# count  1319.000000  1319.000000  1319.000000  1319.000000  1319.000000
# mean    185.057071     0.440485     0.068992     0.993935    55.267627
# std     272.218917     0.496634     0.253536     1.247745    66.271746
# ...

# %%
# %matplotlib inline

# %%
df.hist(bins=50, figsize=(20,15));
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y=df.card
X=df.drop("card",axis=1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.20)

# %%
len(y_test)
# Out:
# 264

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model= LogisticRegression(random_state=1)
log_model.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=1, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
prediction=log_model.predict(X_test)

# %%
from  sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,prediction)
# Out:
# array([[ 58,   2],
#        [  6, 198]], dtype=int64)
